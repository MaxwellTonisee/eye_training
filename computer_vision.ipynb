# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import cv2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 5
#       1 import numpy as np
#       2 import pandas as pd
#       3 import os
#       4 import matplotlib.pyplot as plt
# ----> 5 import tensorflow as tf
#       6 import cv2
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
tensorflowjs_converter --input_format keras models/blinkdetection.h5 models/blinkdetection_tfjs
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 tf.keras.models.load('models/blinkdetection.h5')
#
# NameError: name 'tf' is not defined

# %% [markdown]
# import glob
#
#
# cat_files = glob('../data_v2/test/center/*.jpg')
# print(len(cat_files))
